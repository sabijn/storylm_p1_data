# %%
import datasets

# %%
tinystories = datasets.load_dataset('roneneldan/TinyStories')

# %%
tinystories
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 2119719
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 21990
#     })
# })
