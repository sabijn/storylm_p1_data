# %%
from evaluate import load

import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd

# %%
CC_dataset = load_dataset('codymd/cc100_en_sample')
CC_dataset_text = CC_dataset['train']['text']

# %%
tinystories = load_dataset('roneneldan/TinyStories', split='train[:1%]')

# %%
df_tinystories = pd.DataFrame(list(tinystories['text']), columns=['story'])
tiny_tinystories = df_tinystories[:1200].copy()

# %%
df_narrative = pd.read_csv('datasets/Nicolopoulou/nicolopoulou_text.csv').drop(['Unnamed: 0'], axis=1)
df_narrative
# Out:
#                                                    text
# 0     I go to bed. Joella tucks me in. I get my jamm...
# 1     my mom picks me up. I go home with my mom. and...
# 2     two princesses first and two babies. and a mot...
# 3     a princess and a queen and a castle. and two p...
# 4     a princess and then a prince married her. and ...
# ...                                                 ...
# 1224  once there was a Power Puff girl. and that was...
# 1225  once there was a dinosaur. and then there was ...
# 1226  once there was the Power Puff Girl Gang. and t...
# 1227  once there was a karate master. and he killed ...
# 1228  once there was a hammerhead shark. and he almo...
#
# [1229 rows x 1 columns]

# %%
mauve = load('mauve')

p_text = CC_dataset_text[:1200]
q_text = tiny_tinystories['story'].to_list()

out_ref_fake = mauve.compute(
    predictions=p_text,
    references=q_text,
    num_buckets=30,          
    featurize_model_name="gpt2",
    verbose=True,
    mauve_scaling_factor=0.8
)
out_ref_fake.mauve
# plt.plot(out.divergence_curve[:, 1], out.divergence_curve[:, 0])
# Out:
# Tokenizing text...
# Featurizing tokens
# Featurizing p:   0%|          | 0/1200 [00:00<?, ?it/s]
# Tokenizing text...
# Featurizing tokens
# Featurizing q:   0%|          | 0/1200 [00:00<?, ?it/s]
# seed = 25
# performing clustering in lower dimension = 2
# Clustering 2400 points in 3D to 30 clusters, redo 5 times, 500 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 499 (0.28 s, search 0.17 s): objective=7.1893 imbalance=1.245 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 499 (0.38 s, search 0.22 s): objective=8.6379 imbalance=1.243 nsplit=0
# Outer iteration 2 / 5
#   Iteration 499 (0.46 s, search 0.25 s): objective=8.77139 imbalance=1.167 nsplit=0
# Outer iteration 3 / 5
#   Iteration 499 (0.54 s, search 0.29 s): objective=7.09256 imbalance=1.213 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 499 (0.61 s, search 0.32 s): objective=6.89238 imbalance=1.237 nsplit=0
# Objective improved: keep new clusters
# kmeans time: 0.62 s
# total discretization time: 0.73 seconds
# 0.6121043250023597

# %%
p_text = CC_dataset_text[:1229]
q_text = df_narrative['text'].to_list()

# out = mauve.compute(
#     predictions=p_text,
#     references=q_text,
#     num_buckets=30,          
#     featurize_model_name="gpt2",   
#     device_id=-1,                  # force CPU featurization
#     max_text_length=256,           # default is 1024
#     kmeans_num_redo=1,             
#     kmeans_max_iter=100,           
#     pca_max_data=5000,            # cap PCA sample (use -1 to use all)
#     verbose=True
# )

out_ref_real = mauve.compute(
    predictions=p_text,
    references=q_text,
    num_buckets=30,          
    featurize_model_name="gpt2",
    verbose=True,
    mauve_scaling_factor=0.8
)
out_ref_real.mauve
# Out:
# Tokenizing text...
# Featurizing tokens
# Featurizing p:   0%|          | 0/1229 [00:00<?, ?it/s]
# Tokenizing text...
# Featurizing tokens
# Featurizing q:   0%|          | 0/1229 [00:00<?, ?it/s]
# seed = 25
# performing clustering in lower dimension = 1
# Clustering 2458 points in 2D to 30 clusters, redo 5 times, 500 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 499 (0.30 s, search 0.17 s): objective=5.14564 imbalance=1.489 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 499 (0.38 s, search 0.21 s): objective=5.47321 imbalance=1.289 nsplit=0
# Outer iteration 2 / 5
#   Iteration 499 (0.45 s, search 0.24 s): objective=4.4593 imbalance=1.369 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 499 (0.55 s, search 0.29 s): objective=5.52112 imbalance=1.249 nsplit=0
# Outer iteration 4 / 5
#   Iteration 499 (0.64 s, search 0.33 s): objective=4.16673 imbalance=1.336 nsplit=0
# Objective improved: keep new clusters
# kmeans time: 0.64 s
# total discretization time: 0.77 seconds
# 0.6069190012525807

# %%
p_text = tiny_tinystories['story'].to_list()
q_text = df_narrative['text'].to_list()[:1200]

out_fake_real = mauve.compute(
    predictions=p_text,
    references=q_text,
    num_buckets=30,          
    featurize_model_name="gpt2",
    verbose=True,
    mauve_scaling_factor=0.8
)
out_fake_real.mauve
# Out:
# Tokenizing text...
# Featurizing tokens
# Featurizing p:   0%|          | 0/1200 [00:00<?, ?it/s]
# Tokenizing text...
# Featurizing tokens
# Featurizing q:   0%|          | 0/1200 [00:00<?, ?it/s]
# seed = 25
# performing clustering in lower dimension = 2
# Clustering 2400 points in 3D to 30 clusters, redo 5 times, 500 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 499 (0.35 s, search 0.08 s): objective=2.20692 imbalance=1.609 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 499 (0.43 s, search 0.11 s): objective=2.14978 imbalance=1.598 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 499 (0.50 s, search 0.14 s): objective=2.19426 imbalance=1.527 nsplit=0
# Outer iteration 3 / 5
#   Iteration 499 (0.62 s, search 0.21 s): objective=2.04714 imbalance=1.709 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 499 (0.68 s, search 0.23 s): objective=2.19637 imbalance=1.517 nsplit=0
# kmeans time: 0.69 s
# total discretization time: 0.8 seconds
# 0.6380613182791007
